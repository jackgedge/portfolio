# %%
import pandas as pd

# %%
file_path='/home/jack/Code/cars/df_VEH0220.csv'
df=pd.read_csv(file_path, encoding="cp1252")

# %%
df.head()
# Out:
#   BodyType    Make    GenModel                 Model    Fuel EngineSizeSimple  \
# 0     Cars  ABARTH  ABARTH 124       124 GT MULTIAIR  PETROL             1400
# 1     Cars  ABARTH  ABARTH 124       124 GT MULTIAIR  PETROL             1400
# 2     Cars  ABARTH  ABARTH 124  124 GT MULTIAIR AUTO  PETROL             1400
# 3     Cars  ABARTH  ABARTH 124  124 GT MULTIAIR AUTO  PETROL             1400
# 4     Cars  ABARTH  ABARTH 500                   500  PETROL             1400
#
#      EngineSizeDesc LicenceStatus  2025  2024  2023  2022  2021  2020  2019  \
# 0  1301cc to 1400cc      Licensed    16    14    16    17    16    18    18
# 1  1301cc to 1400cc          SORN     3     5     4     3     3     2     2
# 2  1301cc to 1400cc      Licensed    25    25    26    25    26    26    26
# 3  1301cc to 1400cc          SORN     4     4     3     3     3     2     1
# 4  1301cc to 1400cc          SORN   532   422   348   284   240   242   174
#
#    2018  2017  2016  2015  2014
# ...

# %%
df.describe()
# Out:
#                 2025           2024           2023           2022  \
# count  366116.000000  366116.000000  366116.000000  366116.000000
# mean      134.831190     132.055889     129.936954     127.534467
# std      1083.617594    1074.875816    1067.366763    1062.164989
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       1.000000       0.000000       0.000000
# 50%         2.000000       2.000000       2.000000       2.000000
# 75%        19.000000      17.000000      16.000000      15.000000
# max    226700.000000  232335.000000  237349.000000  241270.000000
#
#                 2021           2020           2019           2018  \
# count  366116.000000  366116.000000  366116.000000  366116.000000
# mean      125.695067     124.067345     123.089611     120.528469
# std      1061.300116    1065.609363    1082.750912    1086.021705
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['BodyType', 'Make', 'GenModel', 'Model', 'Fuel', 'EngineSizeSimple',
#        'EngineSizeDesc', 'LicenceStatus', '2025', '2024', '2023', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014'],
#       dtype='str')

# %%
len(df)
# Out:
# 366116

# %%
df['Make'].nunique()
# Out:
# 944

# %%
df['GenModel'].nunique()
# Out:
# 8377

# %%
df['EngineSizeSimple'].min()
# Out:
# '100'

# %%
# Out:
# EngineSizeSimple
# 2000     50775
# 1600     24988
# 2500     17857
# 2200     15141
# 2300     14235
#          ...
# 13300       12
# 13900       10
# 13400        8
# 13500        6
# 14500        5
# Name: count, Length: 154, dtype: int64
